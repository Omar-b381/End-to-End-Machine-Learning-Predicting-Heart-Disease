# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = r"C:\Users\scan\projects\ML-project3\Predicting heart disease\data\raw\heart_disease_df_1.csv"
df = pd.read_csv(file_path)

# %%
# Exploratery Data Analysis

# %%
df.head()
# Out:
#    age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   52    1  0.0       125  212.0    0      1.0      168      0      NaN
# 1   53    1  0.0       140  203.0    1      0.0      155      1      NaN
# 2   70    1  0.0       145  174.0    0      1.0      125      1      NaN
# 3   61    1  0.0       148  203.0    0      1.0      161      0      NaN
# 4   62    0  0.0       138  294.0    1      1.0      106      0      NaN
#
#    slope  ca  thal  target
# 0      2   2     3       0
# 1      0   0     3       0
# 2      0   0     3       0
# 3      2   1     3       0
# 4      1   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1076 entries, 0 to 1075
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1076 non-null   int64
#  1   sex       1076 non-null   int64
#  2   cp        1023 non-null   float64
#  3   trestbps  1076 non-null   int64
#  4   chol      1076 non-null   float64
#  5   fbs       1076 non-null   int64
#  6   restecg   1076 non-null   float64
#  7   thalach   1076 non-null   int64
#  8   exang     1076 non-null   int64
#  9   slope     1076 non-null   int64
#  10  ca        1076 non-null   int64
#  11  thal      1076 non-null   int64
#  12  target    1076 non-null   int64
# dtypes: float64(3), int64(10)
# memory usage: 109.4 KB

# %%
df.drop(columns='oldpeak',inplace=True)

# %%
# handling absent values in chol column
mean_value = df['chol'].mean()
df['chol'].fillna(mean_value,inplace=True)

# %%
# handling absent values in restecg column
mean_value = df['restecg'].mean()
df['restecg'].fillna(mean_value,inplace=True)
# Out:
# C:\Users\scan\AppData\Local\Temp\ipykernel_20896\2053708050.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['restecg'].fillna(mean_value,inplace=True)

# %%
# handling absent values in cp column
mean_value = df['cp'].mean()
df['cp'].fillna(mean_value,inplace=True)
# Out:
# C:\Users\scan\AppData\Local\Temp\ipykernel_20896\3568966732.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cp'].fillna(mean_value,inplace=True)

# %%
df['target'].value_counts(normalize=True)
# Out:
# target
# 1    0.512082
# 0    0.487918
# Name: proportion, dtype: float64

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps         chol  \
# count  1076.000000  1076.000000  1076.000000  1076.000000  1076.000000
# mean     54.548327     0.690520     0.947214   131.752788   245.537708
# std       9.002247     0.462494     0.999139    17.471844    49.041357
# min      29.000000     0.000000     0.000000    94.000000   126.000000
# 25%      48.000000     0.000000     0.000000   120.000000   212.000000
# 50%      56.000000     1.000000     0.947214   130.000000   243.000000
# 75%      61.000000     1.000000     2.000000   140.000000   274.000000
# max      77.000000     1.000000     3.000000   200.000000   564.000000
#
#                fbs      restecg      thalach        exang        slope  \
# count  1076.000000  1076.000000  1076.000000  1076.000000  1076.000000
# mean      0.148699     0.527237   149.152416     0.331784     1.385688
# std       0.355957     0.516011    22.813766     0.471073     0.618279
# ...

# %%
df['chol'].plot(kind='hist')
plt.title("Distribuation of chol column")
plt.show()

# %%
for col in df.columns:
    sns.boxplot(x=df[col])
    plt.title(f"Distribuation of {col}")
    plt.show()
